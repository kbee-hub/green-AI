# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
number_list=[22,33,44,55,]
number_Series=pd.Series(number_list, index=['a','b','c','d'],name='number')
print(number_Series)
# Out:
# a    22
# b    33
# c    44
# d    55
# Name: number, dtype: int64

# %%
std_dict = {'name':['ash','sak','kav','nith'], 'age':[20,30,40,50] , 'city':['ten','sct','mdu','slm']}
df = pd.DataFrame(std_dict)
print(df)
# Out:
#    name  age city
# 0   ash   20  ten
# 1   sak   30  sct
# 2   kav   40  mdu
# 3  nith   50  slm

# %%
tips = pd.read_csv("C:/kb project 2025/dataset/tips.csv")
tips.head(50)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns

# %%
sns.displot(tips["size"], kde = True)

# %%
sns.pairplot(tips)

# %%
tips1 = tips[["total_bill","tip","size"]]
sns.heatmap(tips1.corr(),cmap="coolwarm",annot=True)
# Out:
# <Axes: >

# %%
sns.barplot(x='smoker',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill", data = tips, palette='pastel')
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_12152\3163069579.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day",y="total_bill", data = tips, palette='pastel')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="sex",y="total_bill",data=tips, hue ="day")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>
